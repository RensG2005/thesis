# %%
from utils.plot_line import plot_line_graph
from consumersentiment import load_df
# Out:
# /home/rens/scriptie/consumersentiment/consumersentiment.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   cs_sentiment_df["date"] = pd.to_datetime(cs_sentiment_df["date"])

# %%
cs_sentiment_df = load_df()
print(cs_sentiment_df.columns)
# Out:
# Index(['date', 'Consumer confidence', 'Economic climate', 'Willingness to buy',
#        'Economic situation last 12 months',
#        'Economic situation next 12 months',
#        'Financial situation last 12 months',
#        'Financial situation next 12 months',
#        'Right time to make large purchases', 'Unnamed: 9',
#        'normalized_Consumer confidence', 'normalized_Economic climate',
#        'normalized_Willingness to buy',
#        'normalized_Economic situation next 12 months'],
#       dtype='object')

# %%
plot_line_graph(
            df=cs_sentiment_df,
            x_column='date', 
            y_column=['normalized_Consumer confidence', 'normalized_Economic climate','normalized_Willingness to buy', 'normalized_Economic situation next 12 months'],
            title='Consumer confidence variables by month',
            xlabel='Year_Month',
            ylabel='Normalized consumer confidence variables [-5, 5]',
            grid=True)



# plot_line_graph(
#             df=cs_sentiment_df,
#             x_column='date', 
#             y_column='normalized_Consumer confidence',
#             title='Consumer confidence by month',
#             xlabel='Year_Month',
#             ylabel='Normalized consumer confidence',
#             color='blue',
#             linestyle='-',
#             grid=True)
# Out:
# (<Figure size 1500x600 with 1 Axes>,
#  <Axes: title={'center': 'Consumer confidence variables by month'}, xlabel='Year_Month', ylabel='Normalized consumer confidence variables [-5, 5]'>)
