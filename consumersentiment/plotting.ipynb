# %%
from utils.plot_line import plot_line_graph
from consumersentiment import load_df
# Out:
# PCA results saved to: /home/rens/scriptie/consumersentiment/consumer_sentiment_pca.csv
# PCA Explained Variance: 0.7893 (78.93%)
#
# Component Loadings (contribution of each feature):
#                                          PC1
# Consumer confidence                 0.394892
# Economic climate                    0.358334
# Willingness to buy                  0.371079
# Economic situation last 12 months   0.369502
# Economic situation next 12 months   0.287140
# Financial situation last 12 months  0.323536
# Financial situation next 12 months  0.349853
# Right time to make large purchases  0.363185
#
# PCA results are available at: /home/rens/scriptie/consumersentiment/consumer_sentiment_pca.csv
#
# PCA Results (first 5 rows):
#         date  consumer_sentiment_pca
# 0 1986-04-01                0.449580
# 1 1986-05-01                1.012103
# 2 1986-06-01                1.778341
# 3 1986-07-01                2.292954
# 4 1986-08-01                2.460690
# /home/rens/scriptie/consumersentiment/consumersentiment.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["date"] = pd.to_datetime(df["date"])

# %%
cs_sentiment_df = load_df()
print(cs_sentiment_df.columns)
# Out:
# PCA results saved to: /home/rens/scriptie/consumersentiment/consumer_sentiment_pca.csv
# PCA Explained Variance: 0.7893 (78.93%)
#
# Component Loadings (contribution of each feature):
#                                          PC1
# Consumer confidence                 0.394892
# Economic climate                    0.358334
# Willingness to buy                  0.371079
# Economic situation last 12 months   0.369502
# Economic situation next 12 months   0.287140
# Financial situation last 12 months  0.323536
# Financial situation next 12 months  0.349853
# Right time to make large purchases  0.363185
# Index(['date', 'consumer_sentiment_pca', 'Consumer confidence',
#        'Economic climate', 'Willingness to buy',
#        'Economic situation last 12 months',
#        'Economic situation next 12 months',
#        'Financial situation last 12 months',
#        'Financial situation next 12 months',
#        'Right time to make large purchases'],
#       dtype='object')
# /home/rens/scriptie/consumersentiment/consumersentiment.py:16: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["date"] = pd.to_datetime(df["date"])

# %%
plot_line_graph(
            df=cs_sentiment_df,
            x_column='date', 
            y_column=['consumer_sentiment_pca', 'Consumer confidence',
       'Economic climate', 'Willingness to buy',
       'Economic situation next 12 months',
       'Financial situation next 12 months',a
       'Right time to make large purchases'],
            title='Consumer confidence variables by month',
            xlabel='Year_Month',
            ylabel='Normalized consumer confidence variables [-5, 5]',
            grid=True)
# Out:
# (<Figure size 1500x600 with 1 Axes>,
#  <Axes: title={'center': 'Consumer confidence variables by month'}, xlabel='Year_Month', ylabel='Normalized consumer confidence variables [-5, 5]'>)
