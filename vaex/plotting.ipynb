# %%
from utils.plot_line import plot_line_graph
import pandas as pd
# Out:
# ['/home/rens/scriptie/vaex', '/home/rens/scriptie', '/home/rens/anaconda3/lib/python312.zip', '/home/rens/anaconda3/lib/python3.12', '/home/rens/anaconda3/lib/python3.12/lib-dynload', '', '/home/rens/anaconda3/lib/python3.12/site-packages', '/home/rens/anaconda3/lib/python3.12/site-packages/setuptools/_vendor']

# %%
volatility_df_daily = pd.read_csv("investing.comVAEXmonthly.csv")

volatility_df_daily["date"] = pd.to_datetime(volatility_df_daily["date"])

volatility_df_daily = volatility_df_daily.sort_values('date')

# %%
plot_line_graph(
            df=volatility_df_daily,
            x_column='date', 
            y_column=['Open'],
            title='Consumer confidence variables by month',
            xlabel='Year_Month',
            ylabel='Normalized consumer confidence variables [-5, 5]',
            grid=True)
# Out:
# (<Figure size 1500x600 with 1 Axes>,
#  <Axes: title={'center': 'Consumer confidence variables by month'}, xlabel='Year_Month', ylabel='Normalized consumer confidence variables [-5, 5]'>)
